# %%
import numpy as np
z=np.array([[1,2,34],[2,34,8]])
z.dtype
z1=np.eye((3))
z1
l=[1,2,3,'r']
#print(np.ndim(l))
z=np.ones(((11,4,2)))
z
z = np.random.rand(2, 5,5)
#print(z)
#print(np.ndim(z))
#print(np.zeros((2,4,4)))
l=np.random.rand(2,4)
#print(l)
#print(np.asarray(l))
l1=np.copy(l)
l2=l
l1[0][1]=45
#print(l1)
l2[0][3]=8989898
#print(l2)
#print(l)
import numpy as np

# Original array
a = np.array([1, 2, 3, 4, 5])

# Deep copy
c = a.copy()

# Modifying the deep copy
c[0] = 10

#print("Original array:", a)  # Original array is not affected
#print("Deep copy:", c)
import numpy as np

# Original array
a = np.array([1, 2, 3, 4, 5])

# Shallow copy
b = a

# Modifying the shallow copy
b[0] = 10

#print("Original array:", a)  # Original array is affected
#print("Shallow copy:", b)
z=np.fromfunction(lambda a ,b :a==b ,shape=(2,3)) # return t and f values if a==b
z=np.shape=(2,3) # no of ros and columns
np.ndim(z)#no of dimension
z = np.random.randint(0, 10, (2, 3))
z=list(range(2,10,2))#no used for float and does not work with np alway used in list not with array
#print(z)
z=np.arange(1.10,10.2) #used in both float and int at last has step size and used only 1D array
#print(z)
z=np.linspace(1,5,10)# doesnot gives equal distant value also work in float anmd at last has no of elements
#print(z)
z=np.logspace(1,3,3,base=2) # return equal distant value with some base value
z=np.ones((3,2))
z1=z=np.ones((2,2))
z*z1
z@z1 #matrix multiplication
x=z.T # transpose of matrix
x=np.empty((2,19,3))#random array output
#x=np.random.rand(6,5,2)
#x
import pandas as pd
z=pd.DataFrame([[1,2,3],[234,4,5]])
z.index=[34,34]
z
import random
x=random.choice("rizwankhan") #for random choice
x=random.choice((1,2,3,4,5)) #for random choice
x=random.randrange(1,10)
import random

# Define your list
lis = [1, 5, 3, 8, 9]

# Shuffle the list in place
random.shuffle(lis)

# Print the shuffled list
print(lis)
x=random.randn(2,3)
x=np.random.rand()
x=random.random_sample() #between 0 and 1 <<-->> exclude
x=np.random.randint(1,2,(2,3))
x.size
x.size
x.ndim
x=array
import numpy as np
import pandas as pd
print(np.random.randint(2,8,size=(2,4)))
import numpy as np

# Generate a random 4x4 array
x = np.random.randint(2, 8, size=(4, 4))
print(x)
print()
'''
# Reshape the array to a 2x8 array
print( x.reshape(2, 8))
print()
print( x.reshape(2,-1))# autodetect no of columns
print()
print( x.reshape(-1, 4)) # autodetect no of rows
print()
print(np.reshape(2,8).base)'''

x=np.zeros((1,1,1,2,3)) # 5D array 2+1+1+1
x
x.ndim
x.shape
print(x[0,[1,3]])
print(x[0:3,[1,3]]) #rows to rows then
print(np.min(x))
print(x[0:2,1:3])
print(np.max(x))
print(np.sum(x))
#This will print the sum of elements along each row of the array x
print(np.sum(x, axis=1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-171-a1f48ea61a9a> in <cell line: 54>()
#      52 np.ndim(z)#no of dimension
#      53 z = np.random.randint(0, 10, (2, 3))
# ---> 54 z=list(range(2,10,2))#no used for float and does not work with np alway used in list not with array
#      55 #print(z)
#      56 z=np.arange(1.10,10.2) #used in both float and int at last has step size and used only 1D array
#
# TypeError: 'list' object is not callable
